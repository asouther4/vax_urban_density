# %% [markdown]
# # Basic Agent-Based Simulation of an SEIR Model
#
# **Author: Andrew Souther, Date: September 2020**
#
# **To get started, we import a few packages for this notebook**
#
# We use pandas to work with json data in an efficient way, random is for testing Proposition 2, and matplotlib/seaborn are for plotting.

# %%
# %matplotlib inline
#importing all the packages we need
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# Next, import the whole experiment_data log file into one big dataframe.

# %%
#TODO: import infection data

# %% [markdown]
# Look at the spread of infection

# %%
#grab data on infections over time using the "infection" data flag. 
infection_df = df.loc[df["data_flag"] == "infection"]

#generate a list of the unique runs, pick a random run, and find all data from that single run
list_of_runs = infection_df["inst_unique_id"].unique()
random_run = random.choice(list_of_runs)
random_run_df = infection_df.loc[infection_df["inst_unique_id"] == random_run]

#graph infections over time
fig, ax = plt.subplots()
ax.plot(random_run_df["time_period"], random_run_df["current_infections"])
ax.set(xlabel='Time Period (t)', ylabel='Number of Agents Currently Infected',
        title='Number of agents currently infected during time period')
ax.plot
# Out:
# <bound method Axes.plot of <matplotlib.axes._subplots.AxesSubplot object at 0x000001E31170EAC8>>
